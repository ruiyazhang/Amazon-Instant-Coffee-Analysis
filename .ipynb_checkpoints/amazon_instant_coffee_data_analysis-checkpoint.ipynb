# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Data Cleaning

# %%
coffee=pd.read_csv('instant_coffee_amazon.csv')

# %%
len(coffee)
# Out:
# 4572

# %%
dups = pd.concat(g for _, g in coffee.groupby("ASIN") if len(g) > 1)
dups.head(4)
# Out:
#             ASIN                                                FBA  \
# 3821  B0001MAF2U    Sold by 2ndTimesaCharm and Fulfilled by Amazon.
# 3862  B0001MAF2U    Sold by 2ndTimesaCharm and Fulfilled by Amazon.
# 3912  B000H299AI  Sold by OnlinePrimeBrands and Fulfilled by Ama...
# 3952  B000H299AI  Sold by OnlinePrimeBrands and Fulfilled by Ama...
#
#       amazon_choice  answered_questions                brand   price  \
# 3821          False                 7.0      Brand: Fireside  $14.49
# 3862          False                 7.0      Brand: Fireside  $14.49
# 3912          False                 3.0  Brand: Caffe D'Vita  $36.99
# 3952          False                 3.0  Brand: Caffe D'Vita  $36.99
#
#                                      productDescription  \
# 3821  The buttery, rich, traditional flavor you love...
# 3862  The buttery, rich, traditional flavor you love...
# 3912  Our Coffee and premium ingredients create a ri...
# 3952  Our Coffee and premium ingredients create a ri...
#
#                                      product_image_urls  \
# 3821  https://m.media-amazon.com/images/I/71Fl7x5EPA...
# 3862  https://m.media-amazon.com/images/I/71Fl7x5EPA...
# 3912  https://m.media-amazon.com/images/I/61ID8KILXm...
# 3952  https://m.media-amazon.com/images/I/61ID8KILXm...
#
#                                            product_name  \
# 3821  Fireside Coffee Instant Cafe Mocha (Butter Rum...
# 3862  Fireside Coffee Instant Cafe Mocha (Butter Rum...
# 3912  Caffe D’Vita French Vanilla Cappuccino, 6 Pack...
# 3952  Caffe D’Vita French Vanilla Cappuccino, 6 Pack...
#
#                                             product_url  ... rating_4_star  \
# 3821  https://www.amazon.com/Fireside-Coffee-Instant...  ...           47%
# 3862  https://www.amazon.com/Fireside-Coffee-Instant...  ...           47%
# 3912  https://www.amazon.com/Caffe-DVita-French-Vani...  ...            6%
# 3952  https://www.amazon.com/Caffe-DVita-French-Vani...  ...            6%
#
#      rating_5_star rating_avg rating_nums shipping_weight  subscribe  \
# 3821           43%        4.2        18.0    9.6 ounces (        NaN
# 3862           43%        4.2        18.0    9.6 ounces (        NaN
# 3912           75%        4.4        70.0    7.9 pounds (        NaN
# 3952           75%        4.4        70.0    7.9 pounds (        NaN
#
#       subscribe_price_15per subscribe_price_5per top_sales_rank  \
# 3821                    NaN                  NaN         1604.0
# 3862                    NaN                  NaN         1604.0
# 3912                    NaN                  NaN          455.0
# 3952                    NaN                  NaN          455.0
#
#                             unit_price
# 3821                   ($14.49 / Item)
# 3862                   ($14.49 / Item)
# 3912  12 x 9 x 5.5 inches ; 6.9 pounds
# 3952  12 x 9 x 5.5 inches ; 6.9 pounds
#
# [4 rows x 23 columns]

# %%
coffee.sort_values("ASIN", inplace = True)
coffee.drop_duplicates(subset ="ASIN", inplace = True)
len(coffee)
# Out:
# 4369

# %%
coffee.set_index('ASIN',inplace=True)

# %%
coffee.sample(10)
# Out:
#                                                           FBA  amazon_choice  \
# ASIN
# B0787M2BMT             Ships from and sold by GreenPeaceLove.          False
# B07XVPWG7V            Ships from and sold by CoffeeLover1111.          False
# B01JB758WW        Ships from and sold by MyOfficeInnovations.          False
# B0086JFS72                                                NaN          False
# B01C9DEL46   Sold by AMPossibilities and Fulfilled by Amazon.          False
# B07KFKGV22            Ships from and sold by CoffeeLover1111.          False
# B01LXJ25R7  Sold by Coffee For Health LLC and Fulfilled by...           True
# B07MZPQ8NR                Ships from and sold by PrimeHub CA.          False
# B00IWT6DXY                Ships from and sold by Kawaii-land.          False
# B078WT84MS                                                NaN          False
#
#             answered_questions                            brand    price  \
# ASIN
# B0787M2BMT                 NaN                Brand: Gano Excel   $38.22
# B07XVPWG7V                 NaN  Brand: GANO EXCEL INTERNATIONAL   $69.00
# B01JB758WW                 NaN               Brand: Office Snax   $24.79
# B0086JFS72                 NaN             Brand: Caffe d'Amore   $26.62
# B01C9DEL46                 NaN           Brand: Fireside Coffee   $23.29
# B07KFKGV22                 NaN               Brand: Organo Gold  $299.98
# B01LXJ25R7                13.0                Brand: Gano Excel   $15.99
# B07MZPQ8NR                 NaN                     Brand: SUPER   $16.29
# B00IWT6DXY                 NaN                     Brand: Fitne   $17.75
# B078WT84MS                 NaN                Brand: Gano Excel      NaN
#
#                                            productDescription  \
# ASIN
# B0787M2BMT  GANOCAFÉ CLASSIC is an instant black coffee bl...
# B07XVPWG7V  GanoCafé 3-in-1 is the perfect blend of qualit...
# B01JB758WW  Medium roast, 100% Arabica coffee with no arti...
# B0086JFS72  Zero grams Trans Fat per serving. No Hydrogena...
# B01C9DEL46  Each can contains 14 8-oz. servings. Great to ...
# B07KFKGV22  100% Certified Organic Ganoderma Lucidum. More...
# B01LXJ25R7  GanoCafé 3-in-1 is the perfect blend of qualit...
# B07MZPQ8NR  "8 In 10 Blind-Test Participants Prefer The Ta...
# B00IWT6DXY            Start your day fresh\nBeautiful healthy
# B078WT84MS  Ganocafe Mocha with is an instant coffee blend...
#
#                                            product_image_urls  \
# ASIN
# B0787M2BMT  https://m.media-amazon.com/images/I/71NWzAiJ7v...
# B07XVPWG7V  https://m.media-amazon.com/images/I/6185W0qTmv...
# B01JB758WW  https://m.media-amazon.com/images/I/71uB6BexsH...
# B0086JFS72  https://m.media-amazon.com/images/I/81luMXVEeD...
# B01C9DEL46  https://m.media-amazon.com/images/I/31N9RPUkmY...
# B07KFKGV22  https://m.media-amazon.com/images/I/71WFnnqDcZ...
# B01LXJ25R7  https://m.media-amazon.com/images/I/81XliIP9CT...
# B07MZPQ8NR  https://m.media-amazon.com/images/I/51L2C2Gp1N...
# B00IWT6DXY  https://m.media-amazon.com/images/I/81UdQLZ+Mv...
# B078WT84MS  https://m.media-amazon.com/images/I/71zCsRTTEc...
#
#                                                  product_name  \
# ASIN
# B0787M2BMT  3 Boxes Gano Excel Black Coffee Classic Ganode...
# B07XVPWG7V  NEW PACKAGE 4 Box Gano Excel Ganocafe Ganolici...
# B01JB758WW  Office Snax 00058 100% Pure Arabica Coffee, Or...
# B0086JFS72   Caffe D' Amore Mocha Gouremt Beverage Mix 28 oz.
# B01C9DEL46  Gourmet Cafe Mocha Chocolate Instant Flavored ...
# B07KFKGV22  12 box Organo Gold Black Coffee + 4 Box Nugano...
# B01LXJ25R7                                  Gano Excel 3-in-1
# B07MZPQ8NR  2-Pack Super Essenso 3-In1 Microground Coffee/...
# B00IWT6DXY                   Instant Coffee Mix with Collagan
# B078WT84MS        8 boxes Gano Excel GanoCafe Ganoderma Mocha
#
#                                                   product_url rating_1_star  \
# ASIN
# B0787M2BMT  https://www.amazon.com/Gano-Excel-Classic-Gano...            0%
# B07XVPWG7V  https://www.amazon.com/PACKAGE-Ganocafe-Ganoli...            0%
# B01JB758WW  https://www.amazon.com/Office-Snax-Arabica-Cof...            0%
# B0086JFS72  https://www.amazon.com/Caffe-Amore-Mocha-Goure...            0%
# B01C9DEL46  https://www.amazon.com/Gourmet-Chocolate-Insta...            0%
# B07KFKGV22  https://www.amazon.com/Organo-Gold-Coffee-Expr...            0%
# B01LXJ25R7  https://www.amazon.com/Gano-Excel-Caf%C3%A9/dp...           10%
# B07MZPQ8NR  https://www.amazon.com/Super-Microground-Signa...            0%
# B00IWT6DXY  https://www.amazon.com/Instant-Coffee-Mix-with...            0%
# B078WT84MS  https://www.amazon.com/boxes-Gano-Excel-GanoCa...            0%
#
#             ... rating_4_star rating_5_star rating_avg rating_nums  \
# ASIN        ...
# B0787M2BMT  ...            0%          100%        5.0         1.0
# B07XVPWG7V  ...            0%            0%        NaN         NaN
# B01JB758WW  ...            0%            0%        NaN         NaN
# B0086JFS72  ...            0%            0%        NaN         NaN
# B01C9DEL46  ...            0%            0%        NaN         NaN
# B07KFKGV22  ...            0%            0%        NaN         NaN
# B01LXJ25R7  ...            6%           79%        4.4       148.0
# B07MZPQ8NR  ...            0%            0%        NaN         NaN
# B00IWT6DXY  ...            0%            0%        NaN         NaN
# B078WT84MS  ...            0%            0%        NaN         NaN
#
#             shipping_weight  subscribe subscribe_price_15per  \
# ASIN
# B0787M2BMT              NaN        NaN                   NaN
# B07XVPWG7V              NaN        NaN                   NaN
# B01JB758WW     2.1 pounds (        NaN                   NaN
# B0086JFS72       1.9 pounds        NaN                   NaN
# B01C9DEL46       2 pounds (        NaN                   NaN
# B07KFKGV22              NaN        NaN                   NaN
# B01LXJ25R7     1.1 pounds (        NaN                   NaN
# B07MZPQ8NR              NaN        NaN                   NaN
# B00IWT6DXY              NaN        NaN                   NaN
# B078WT84MS              NaN        NaN                   NaN
#
#            subscribe_price_5per top_sales_rank         unit_price
# ASIN
# B0787M2BMT                  NaN         3423.0   ($12.74 / Count)
# B07XVPWG7V                  NaN            NaN   ($69.00 / Count)
# B01JB758WW                  NaN            NaN    ($0.73 / Ounce)
# B0086JFS72                  NaN         2079.0        1.75 pounds
# B01C9DEL46                  NaN         4936.0   ($23.29 / Count)
# B07KFKGV22                  NaN            NaN  ($299.98 / Count)
# B01LXJ25R7                  NaN           69.0   ($21.76 / Ounce)
# B07MZPQ8NR                  NaN         3579.0    ($8.15 / Count)
# B00IWT6DXY                  NaN            NaN     ($1.78 / Item)
# B078WT84MS                  NaN            NaN    January 9, 2018
#
# [10 rows x 22 columns]

# %%
coffee.FBA
# Out:
# ASIN
# 5480451286                                                 NaN
# 9748836843                  Ships from and sold by Natty Shop.
# B0001MAF1Q     Sold by 2ndTimesaCharm and Fulfilled by Amazon.
# B0001MAF2U     Sold by 2ndTimesaCharm and Fulfilled by Amazon.
# B0001MAF4S    Sold by AMPossibilities and Fulfilled by Amazon.
#                                     ...
# B08DK8JNHC         Ships from and sold by Hula Girl The Store.
# B08DK93YN8         Ships from and sold by Hula Girl The Store.
# B08DKK7N9Y         Ships from and sold by Hula Girl The Store.
# B08DKK8WKS         Ships from and sold by Hula Girl The Store.
# B08DKQLWTM         Ships from and sold by Hula Girl The Store.
# Name: FBA, Length: 4369, dtype: object

# %%
coffee['FBA'] = coffee['FBA'].fillna('')

# %%
coffee['FBA_label'] = ['Amazon product' if x.find('Ships from and sold by Amazon.com')!=-1 else 'FBA' if x.find('Fulfilled by Amazon')!=-1 else '' if x=='' else 'Third Party' for x in coffee['FBA']]

# %%
coffee.sample(100)
# Out:
#                                                           FBA  amazon_choice  \
# ASIN
# B00JZP1GX6              Ships from and sold by thaicoolstore.          False
# B07L63XL7M                 Ships from and sold by JARSA HAUS.          False
# B07LB6SZRP            Ships from and sold by Dream.Big.store.          False
# B07S33F7HQ                                                             False
# B00QN46PWO                  Ships from and sold by Prime CSO.          False
# ...                                                       ...            ...
# B07HQZW5QT                                                             False
# B003LJB8RQ  Sold by Common Cents Distributors and Fulfille...          False
# B07PX46S7T             Ships from and sold by Buy with Aloha.          False
# B01LBFK8N6            Ships from and sold by EuroHomeDesignz.          False
# B07XTBJ7YQ               Ships from and sold by Egyptian MAN.          False
#
#             answered_questions  \
# ASIN
# B00JZP1GX6                 NaN
# B07L63XL7M                 NaN
# B07LB6SZRP                 NaN
# B07S33F7HQ                 NaN
# B00QN46PWO                 NaN
# ...                        ...
# B07HQZW5QT                 NaN
# B003LJB8RQ                 5.0
# B07PX46S7T                 NaN
# B01LBFK8N6                 NaN
# B07XTBJ7YQ                 NaN
#
#                                                         brand    price  \
# ASIN
# B00JZP1GX6                                      Brand: Supper   $29.72
# B07L63XL7M                                      Brand: Cafe21   $53.00
# B07LB6SZRP                                     Brand: Generic   $29.99
# B07S33F7HQ                                 Brand: Gold Choice  $108.00
# B00QN46PWO                                       Brand: SANKA   $36.15
# ...                                                       ...      ...
# B07HQZW5QT                             Brand: Taster's Choice   $21.66
# B003LJB8RQ                                 Brand: Juan Valdez   $39.99
# B07PX46S7T                                 Brand: Royal Mills   $79.98
# B01LBFK8N6                                      Brand: JACOBS   $28.99
# B07XTBJ7YQ  Brand: Instant Nescafe Arabiana Arabic Coffee ...   $49.95
#
#                                            productDescription  \
# ASIN
# B00JZP1GX6                                                NaN
# B07L63XL7M  Cultivated in the perfect climatic conditions ...
# B07LB6SZRP                                                NaN
# B07S33F7HQ  Gold Choice Instant 3 in 1 Durian Penang White...
# B00QN46PWO  Sanka Naturally Decaffeinated Instant Coffee s...
# ...                                                       ...
# B07HQZW5QT  Size:14 Ounce At NESCAFE TASTER'S CHOICE, we h...
# B003LJB8RQ  Buendia by Juan Valdez decaffeinated Instant c...
# B07PX46S7T                                     Made in Hawaii
# B01LBFK8N6  Soluble bean coffee with coffee whitener and s...
# B07XTBJ7YQ  Arabiana is an instant Arabian Coffee with Car...
#
#                                            product_image_urls  \
# ASIN
# B00JZP1GX6  https://m.media-amazon.com/images/I/41brzP7-Go...
# B07L63XL7M  https://m.media-amazon.com/images/I/51MBVChMDG...
# B07LB6SZRP  https://m.media-amazon.com/images/I/41dzNeIDHt...
# B07S33F7HQ  https://m.media-amazon.com/images/I/61FP4qKLqG...
# B00QN46PWO  https://m.media-amazon.com/images/I/41fS6m8BDR...
# ...                                                       ...
# B07HQZW5QT  https://m.media-amazon.com/images/I/71C3DSzxC8...
# B003LJB8RQ  https://m.media-amazon.com/images/I/51yhaWCFBN...
# B07PX46S7T  https://m.media-amazon.com/images/I/510KmtVdUF...
# B01LBFK8N6  https://m.media-amazon.com/images/I/41WKFsdY7f...
# B07XTBJ7YQ  https://m.media-amazon.com/images/I/61xNlb7IfD...
#
#                                                  product_name  \
# ASIN
# B00JZP1GX6        Super Instant Ginseng Coffee 400g (14.1 Oz)
# B07L63XL7M  3 Pack Cafe21 / 2 in 1 Instant Coffeemix No Su...
# B07LB6SZRP   NESCAFE CLASICO Decaf Instant Coffee (Pack of 2)
# B07S33F7HQ  Instant 3 in 1 Durian Penang White Coffee (15 ...
# B00QN46PWO  Sanka Naturally Decaffeinated Instant Coffee (...
# ...                                                       ...
# B07HQZW5QT  Nescafe Taster's Choice House Blend Decaffeina...
# B003LJB8RQ  Buendia by Juan Valdez 100% Colombian Freeze D...
# B07PX46S7T  Royal Mills Iced Cappuccino, Premium Coffee, M...
# B01LBFK8N6  Jacobs 3in1 Cafe Latte Instant Coffee Sticks, ...
# B07XTBJ7YQ  Instant Nescafe Arabiana Arabic Coffee Mix Wit...
#
#                                                   product_url rating_1_star  \
# ASIN
# B00JZP1GX6  https://www.amazon.com/Super-Instant-Ginseng-C...            0%
# B07L63XL7M  https://www.amazon.com/Cafe21-Instant-Coffeemi...            0%
# B07LB6SZRP  https://www.amazon.com/NESCAFE-CLASICO-Decaf-I...            0%
# B07S33F7HQ  https://www.amazon.com/Instant-Durian-Penang-C...            0%
# B00QN46PWO  https://www.amazon.com/Sanka-Naturally-Decaffe...            0%
# ...                                                       ...           ...
# B07HQZW5QT  https://www.amazon.com/Tasters-Choice-Nescafe-...            3%
# B003LJB8RQ  https://www.amazon.com/Buendia-Juan-Valdez-Col...            0%
# B07PX46S7T  https://www.amazon.com/Royal-Mills-Cappuccino-...            0%
# B01LBFK8N6  https://www.amazon.com/Jacobs-3in1-Caffe-Latte...            0%
# B07XTBJ7YQ  https://www.amazon.com/Instant-Nescafe-Arabian...            0%
#
#             ... rating_5_star rating_avg rating_nums shipping_weight  \
# ASIN        ...
# B00JZP1GX6  ...            0%        NaN         NaN   14.1 ounces (
# B07L63XL7M  ...            0%        NaN         NaN             NaN
# B07LB6SZRP  ...            0%        NaN         NaN      3 pounds (
# B07S33F7HQ  ...            0%        NaN         NaN       36 pounds
# B00QN46PWO  ...           54%        4.1         7.0    1.2 pounds (
# ...         ...           ...        ...         ...             ...
# B07HQZW5QT  ...           87%        4.6        48.0        1 pounds
# B003LJB8RQ  ...           69%        4.5        44.0    2.6 pounds (
# B07PX46S7T  ...          100%        5.0         1.0   19.2 pounds (
# B01LBFK8N6  ...          100%        5.0         2.0   12.6 ounces (
# B07XTBJ7YQ  ...          100%        5.0         6.0             NaN
#
#             subscribe  subscribe_price_15per subscribe_price_5per  \
# ASIN
# B00JZP1GX6        NaN                    NaN                  NaN
# B07L63XL7M        NaN                    NaN                  NaN
# B07LB6SZRP        NaN                    NaN                  NaN
# B07S33F7HQ        NaN                    NaN                  NaN
# B00QN46PWO        NaN                    NaN                  NaN
# ...               ...                    ...                  ...
# B07HQZW5QT        NaN                    NaN                  NaN
# B003LJB8RQ        NaN                    NaN                  NaN
# B07PX46S7T        NaN                    NaN                  NaN
# B01LBFK8N6        NaN                    NaN                  NaN
# B07XTBJ7YQ        NaN                    NaN                  NaN
#
#            top_sales_rank           unit_price    FBA_label
# ASIN
# B00JZP1GX6         6526.0          14.1 ounces  Third Party
# B07L63XL7M         4772.0     ($53.00 / Count)  Third Party
# B07LB6SZRP         1258.0     ($29.99 / Count)  Third Party
# B07S33F7HQ            NaN            36 pounds
# B00QN46PWO          968.0       ($1.81 / Item)  Third Party
# ...                   ...                  ...          ...
# B07HQZW5QT          423.0          14.1 ounces
# B003LJB8RQ          670.0      ($3.64 / Ounce)          FBA
# B07PX46S7T          758.0      ($3.33 / Count)  Third Party
# B01LBFK8N6         1869.0      ($1.45 / Count)  Third Party
# B07XTBJ7YQ          996.0  ($1,415.01 / Ounce)  Third Party
#
# [100 rows x 23 columns]

# %%
cols = coffee.columns.tolist()
# cols
cols = cols[-1:] + cols[:-1]
coffee = coffee[cols]

# %%
coffee['answered_questions'] = coffee['answered_questions'].fillna(0)

# %%
coffee.dtypes
# Out:
# FBA_label                 object
# FBA                       object
# amazon_choice               bool
# answered_questions       float64
# brand                     object
# price                     object
# productDescription        object
# product_image_urls        object
# product_name              object
# product_url               object
# rating_1_star             object
# rating_2_star             object
# rating_3_star             object
# rating_4_star             object
# rating_5_star             object
# rating_avg               float64
# rating_nums              float64
# shipping_weight           object
# subscribe                 object
# subscribe_price_15per     object
# subscribe_price_5per      object
# top_sales_rank           float64
# unit_price                object
# dtype: object

# %%
coffee.answered_questions=coffee.answered_questions.astype('int32')

# %%
coffee['brand'] = coffee['brand'].astype('str').str.split('Brand: ').str[-1]
coffee.sample(10)
# Out:
#                  FBA_label                                                FBA  \
# ASIN
# B016PK4ALI     Third Party          Ships from and sold by iSale-uSave (USA).
# B01J68KRV8             FBA     Sold by CATan Trading and Fulfilled by Amazon.
# B00VY5UIWA     Third Party        Ships from and sold by MyOfficeInnovations.
# B08BKYVWSP
# B07S2NMWC6             FBA    Sold by TheEuroStore24 and Fulfilled by Amazon.
# B0852L8HG3             FBA          Sold by Realpick and Fulfilled by Amazon.
# B082YJWHMK             FBA  Sold by King Coffee USA INC and Fulfilled by A...
# B003WEX8PU  Amazon product                  Ships from and sold by Amazon.com
# B085ZYMCVL             FBA          Sold by TUNEZ US and Fulfilled by Amazon.
# B00VR9JVJO             FBA  Sold by Awesome Happiness and Fulfilled by Ama...
#
#             amazon_choice  answered_questions             brand   price  \
# ASIN
# B016PK4ALI          False                   0         Starbucks  $36.85
# B01J68KRV8           True                   0           Nescafé  $10.49
# B00VY5UIWA          False                   0       SBK11018187  $23.07
# B08BKYVWSP          False                   0          Japanese  $54.99
# B07S2NMWC6          False                   0               JDE  $16.09
# B0852L8HG3          False                   0              Kanu  $22.90
# B082YJWHMK          False                   0   TNI King Coffee   $7.70
# B003WEX8PU           True                   3     MAXWELL HOUSE  $19.00
# B085ZYMCVL          False                   0  Nescafe Malaysia  $13.99
# B00VR9JVJO          False                   0        Gano Excel  $99.99
#
#                                            productDescription  \
# ASIN
# B016PK4ALI  4 Boxes of Starbucks French Roast Via, 12 pack...
# B01J68KRV8  NESCAFE Rich makes a deliciously rich tasting ...
# B00VY5UIWA  Take a sip and savor the distinctive flavor of...
# B08BKYVWSP  Deliciousness made with effort over 200 proces...
# B07S2NMWC6                                  Nescafe of Sweden
# B0852L8HG3                                                NaN
# B082YJWHMK                                                are
# B003WEX8PU  Maxwell House Instant Decaffeinated, 8-Ounce J...
# B085ZYMCVL                                       Descriptions
# B00VR9JVJO  A rich blend of gourmet coffee, non-dairy crea...
#
#                                            product_image_urls  \
# ASIN
# B016PK4ALI  https://m.media-amazon.com/images/I/81cMgunVzd...
# B01J68KRV8  https://m.media-amazon.com/images/I/61fShyR8q2...
# B00VY5UIWA  https://m.media-amazon.com/images/I/61OH8W8o4P...
# B08BKYVWSP  https://m.media-amazon.com/images/I/71FR+omOjw...
# B07S2NMWC6  https://m.media-amazon.com/images/I/51HgzsD2oq...
# B0852L8HG3  https://m.media-amazon.com/images/I/71GFACNEFb...
# B082YJWHMK  https://m.media-amazon.com/images/I/71NxRm1-vQ...
# B003WEX8PU  https://m.media-amazon.com/images/I/81VYeqFmkL...
# B085ZYMCVL  https://m.media-amazon.com/images/I/61w9f005DP...
# B00VR9JVJO  https://m.media-amazon.com/images/I/613bxd4Pyd...
#
#                                                  product_name  \
# ASIN
# B016PK4ALI  Starbucks VIA Instant Coffee,French Roast (Pac...
# B01J68KRV8  Nescafe Rich Instant Coffee 170g {Imported fro...
# B00VY5UIWA  Starbucks 11018187 Coffee French Roast Ground ...
# B08BKYVWSP  SUNTORY Craft Boss Black Unsweetened Coffee 50...
# B07S2NMWC6  Nescafe of SWEDEN Original 100% ORGANIC Arabic...
# B0852L8HG3  Maxim KANU Tiramisu Latte 8 Sticks, Vanilla La...
# B082YJWHMK  King Coffee 3in1 instant - Box 6 sticks x 16g ...
# B003WEX8PU  Maxwell House Decaf Original Medium Roast Inst...
# B085ZYMCVL  Nestle Malaysia Nescafe Zero Nescafe 2 In 1 Bl...
# B00VR9JVJO           Gano Excel Ganocafe 3 in 1 8 Box 120 Sac
#
#                                                   product_url  ...  \
# ASIN                                                           ...
# B016PK4ALI  https://www.amazon.com/Starbucks-Via-Instant-C...  ...
# B01J68KRV8  https://www.amazon.com/Nescafe-Rich-Instant-Co...  ...
# B00VY5UIWA  https://www.amazon.com/SBK11018187-UNITED-STAT...  ...
# B08BKYVWSP  https://www.amazon.com/SUNTORY-Craft-Unsweeten...  ...
# B07S2NMWC6  https://www.amazon.com/Nescafe-Original-ORGANI...  ...
# B0852L8HG3  https://www.amazon.com/Maxim-Tiramisu-Latte-va...  ...
# B082YJWHMK  https://www.amazon.com/King-Coffee-3in1-instan...  ...
# B003WEX8PU  https://www.amazon.com/Maxwell-House-Instant-D...  ...
# B085ZYMCVL  https://www.amazon.com/Malaysia-Nescafe-Unswee...  ...
# B00VR9JVJO  https://www.amazon.com/Boxes-Gano-Cafe-Excel-I...  ...
#
#            rating_4_star rating_5_star rating_avg rating_nums shipping_weight  \
# ASIN
# B016PK4ALI           16%           70%        4.4        40.0    7.2 ounces (
# B01J68KRV8           13%           78%        4.6       288.0    1.3 pounds (
# B00VY5UIWA            0%            0%        NaN         NaN      1 pounds (
# B08BKYVWSP            0%            0%        NaN         NaN       12 pounds
# B07S2NMWC6            0%           52%        3.1         2.0    6.4 ounces (
# B0852L8HG3            0%          100%        5.0         1.0   13.4 ounces (
# B082YJWHMK            0%            0%        NaN         NaN    4.6 ounces (
# B003WEX8PU           10%           73%        4.4        86.0    2.2 pounds (
# B085ZYMCVL            0%            0%        3.0         1.0     12 ounces (
# B00VR9JVJO            0%          100%        5.0         2.0    8.5 pounds (
#
#                     subscribe       subscribe_price_15per  \
# ASIN
# B016PK4ALI                NaN                         NaN
# B01J68KRV8                NaN                         NaN
# B00VY5UIWA                NaN                         NaN
# B08BKYVWSP                NaN                         NaN
# B07S2NMWC6                NaN                         NaN
# B0852L8HG3                NaN                         NaN
# B082YJWHMK                NaN                         NaN
# B003WEX8PU  Subscribe & Save:  $16.15\n\n($0.67 /  Ounce)
# B085ZYMCVL                NaN                         NaN
# B00VR9JVJO                NaN                         NaN
#
#                   subscribe_price_5per top_sales_rank        unit_price
# ASIN
# B016PK4ALI                         NaN          199.0   ($0.77 / Count)
# B01J68KRV8                         NaN          457.0  ($10.49 / Count)
# B00VY5UIWA                         NaN         4877.0   ($1.44 / Ounce)
# B08BKYVWSP                         NaN            NaN         12 pounds
# B07S2NMWC6                         NaN         2915.0    ($0.09 / Gram)
# B0852L8HG3                         NaN          756.0   ($1.43 / Count)
# B082YJWHMK                         NaN         2743.0   ($2.27 / Ounce)
# B003WEX8PU  $18.05\n\n($0.75 /  Ounce)          186.0   ($0.79 / Ounce)
# B085ZYMCVL                         NaN          550.0   ($1.32 / Ounce)
# B00VR9JVJO                         NaN         2261.0   ($6.25 / Ounce)
#
# [10 rows x 23 columns]

# %%
coffee['price']=coffee['price'].astype('str').str.replace('$','').str.replace(',','').astype('float')

# %%
coffee=coffee.rename(columns={'price': 'price_in_US_dollars'})

# %%
for i in range(1,6):
    coffee[f'rating_{i}_star']=coffee[f'rating_{i}_star'].str.rstrip('%').astype('float') / 100

# %%
coffee['shipping_weight']=coffee['shipping_weight'].astype('str').str.replace('(','').str.strip()

# %%
coffee[['shipping_weight_number','shipping_weight_unit']] = coffee.shipping_weight.str.split(" ",expand=True)

# %%
coffee['shipping_weight_number']=coffee['shipping_weight_number'].astype('float')

# %%
coffee['shipping_weight_number']=np.where(coffee['shipping_weight_unit'].str.lower()=='pounds',coffee['shipping_weight_number']*16,coffee['shipping_weight_number'])

# %%
coffee.drop(['shipping_weight_unit'], axis=1, inplace=True)

# %%
coffee=coffee.rename(columns={'shipping_weight_number': 'shipping_weight_in_ounces'})

# %%
coffee['subscribe_flag']=(coffee['subscribe'].fillna("").str.find('Subscribe & Save')!=-1)

# %%
coffee[['subscribe_price_15per_2','subscribe_price_15per_unit_price']] = coffee.subscribe_price_15per.str.split("\n\n",expand=True)

# %%
coffee[['subscribe_price_5per','subscribe_price_5per_unit_price']] = coffee.subscribe_price_5per.str.split("\n\n",expand=True)

# %%
coffee['subscribe_price_15per_USdollars']=coffee['subscribe_price_15per_2'].astype('str').str.replace('$','').str.replace(',','').astype('float')

# %%
coffee['subscribe_price_5per_USdollars']=coffee['subscribe_price_5per'].astype('str').str.replace('$','').str.replace(',','').astype('float')

# %%
coffee.drop(['subscribe_price_15per'], axis=1, inplace=True)

# %%
coffee.drop(['subscribe_price_15per_2'], axis=1, inplace=True)

# %%
for i in [5,15]:
    coffee[f'subscribe_price_{i}per_unit_price']=coffee[f'subscribe_price_{i}per_unit_price'].astype('str').str.replace('(','').str.replace(')','').str.replace('$','')
    coffee[[f'subscribe_{i}_unitprice',f'subscribe_{i}_unit']] = coffee[f'subscribe_price_{i}per_unit_price'].str.split(" / ",expand=True)
    coffee[f'subscribe_{i}_unitprice']=coffee[f'subscribe_{i}_unitprice'].replace('None',np.nan).astype('float')

# %%
coffee[coffee.subscribe_flag==True]
# Out:
#                  FBA_label                                                FBA  \
# ASIN
# B000BKGPVM             FBA  Auto-deliveries sold by Cadima Rani and Fulfil...
# B000ESJR20             FBA  Auto-deliveries sold by Vitamins4Beauty and Fu...
# B000W7PUMY  Amazon product                  Ships from and sold by Amazon.com
# B000WE5DPQ             FBA  Auto-deliveries sold by TA National Trading an...
# B0014CVF98  Amazon product                  Ships from and sold by Amazon.com
# ...                    ...                                                ...
# B082VKYZTR             FBA  Auto-deliveries sold by Waka Coffee and Fulfil...
# B082XKWNTM             FBA  Auto-deliveries sold by VitaCup and Fulfilled ...
# B08376RLW6             FBA  Auto-deliveries sold by VitaCup and Fulfilled ...
# B0848T9CM5             FBA  Auto-deliveries sold by THE ELIXIR and Fulfill...
# B085ZL9GX6             FBA  Auto-deliveries sold by TheGroupDeal and Fulfi...
#
#             amazon_choice  answered_questions           brand  \
# ASIN
# B000BKGPVM          False                   0       Big Train
# B000ESJR20           True                  26     Mount Hagen
# B000W7PUMY          False                   0   MAXWELL HOUSE
# B000WE5DPQ           True                   8       Big Train
# B0014CVF98          False                   4         Folgers
# ...                   ...                 ...             ...
# B082VKYZTR          False                   5     Waka Coffee
# B082XKWNTM          False                  11         VitaCup
# B08376RLW6           True                  15         VitaCup
# B0848T9CM5           True                   0      The Elixir
# B085ZL9GX6          False                   0  Grateful Earth
#
#             price_in_US_dollars  \
# ASIN
# B000BKGPVM                35.00
# B000ESJR20                52.48
# B000W7PUMY                32.16
# B000WE5DPQ                23.94
# B0014CVF98                 4.94
# ...                         ...
# B082VKYZTR                11.99
# B082XKWNTM                28.95
# B08376RLW6                14.95
# B0848T9CM5                 8.99
# B085ZL9GX6                45.99
#
#                                            productDescription  \
# ASIN
# B000BKGPVM                       Big train Powdered Drink Mix
# B000ESJR20  Mount Hagen instant organic coffee is organica...
# B000W7PUMY  Maxwell House Instant Coffee, 2-Ounce Jars (Pa...
# B000WE5DPQ  Big Train Blended Ice Coffee Iced Coffee Mix V...
# B0014CVF98  The classic Folgers taste you love is availabl...
# ...                                                       ...
# B082VKYZTR                                                NaN
# B082XKWNTM                                                NaN
# B08376RLW6                                                NaN
# B0848T9CM5  Famous Korean Instant coffee mix that offers d...
# B085ZL9GX6                                                NaN
#
#                                            product_image_urls  \
# ASIN
# B000BKGPVM  https://m.media-amazon.com/images/I/910Rjx5vxJ...
# B000ESJR20  https://m.media-amazon.com/images/I/41-rS8+JUZ...
# B000W7PUMY  https://m.media-amazon.com/images/I/81f03jLw9T...
# B000WE5DPQ  https://m.media-amazon.com/images/I/91civ4ozk9...
# B0014CVF98  https://m.media-amazon.com/images/I/81+lL2oew3...
# ...                                                       ...
# B082VKYZTR  https://m.media-amazon.com/images/I/61lamwjCQM...
# B082XKWNTM  https://m.media-amazon.com/images/I/81FMofEa-A...
# B08376RLW6  https://m.media-amazon.com/images/I/81nu9WU7tX...
# B0848T9CM5  https://m.media-amazon.com/images/I/71ZBlvIp1x...
# B085ZL9GX6  https://m.media-amazon.com/images/I/71b3+eBknV...
#
#                                                  product_name  \
# ASIN
# B000BKGPVM  Big Train Blended Iced Coffee - Toffee Mocha (...
# B000ESJR20  Mount Hagen Organic Freeze Dried Instant Coffe...
# B000W7PUMY  Maxwell House Original Medium Roast Instant Co...
# B000WE5DPQ  Big Train Blended Ice Coffee Iced Coffee Mix V...
# B0014CVF98  Folgers Classic Roast, Instant Coffee Crystals...
# ...                                                       ...
# B082VKYZTR  Waka Coffee Quality Instant Coffee, Indian, Li...
# B082XKWNTM  VitaCup Genius Instant Coffee Stick | Energy &...
# B08376RLW6  VitaCup Slim Instant Coffee Sticks | Diet & Me...
# B0848T9CM5  Korean Instant Coffee Variety Sample Pack Pack...
# B085ZL9GX6  Grateful Earth: Super Brain Blend Instant Coff...
#
#                                                   product_url  ...  \
# ASIN                                                           ...
# B000BKGPVM  https://www.amazon.com/Big-Train-Blended-Iced-...  ...
# B000ESJR20  https://www.amazon.com/Mount-Hagen-Organic-Ins...  ...
# B000W7PUMY  https://www.amazon.com/Maxwell-House-Instant-C...  ...
# B000WE5DPQ  https://www.amazon.com/Big-Train-Blended-Coffe...  ...
# B0014CVF98  https://www.amazon.com/Folgers-Classic-Instant...  ...
# ...                                                       ...  ...
# B082VKYZTR  https://www.amazon.com/Waka-Coffee-Quality-Ins...  ...
# B082XKWNTM  https://www.amazon.com/VitaCup-Instant-Turmeri...  ...
# B08376RLW6  https://www.amazon.com/VitaCup-Metabolism-Garc...  ...
# B0848T9CM5  https://www.amazon.com/Instant-Variety-Packets...  ...
# B085ZL9GX6  https://www.amazon.com/Grateful-Earth-Non-Dair...  ...
#
#             shipping_weight_in_ounces  subscribe_flag  \
# ASIN
# B000BKGPVM                       57.6            True
# B000ESJR20                       75.2            True
# B000W7PUMY                       84.8            True
# B000WE5DPQ                       57.6            True
# B0014CVF98                       10.4            True
# ...                               ...             ...
# B082VKYZTR                        1.6            True
# B082XKWNTM                        3.8            True
# B08376RLW6                        1.8            True
# B0848T9CM5                       11.2            True
# B085ZL9GX6                       14.4            True
#
#             subscribe_price_15per_unit_price  subscribe_price_5per_unit_price  \
# ASIN
# B000BKGPVM                     0.46 /  Ounce                    0.48 /  Ounce
# B000ESJR20                     2.35 /  Ounce                    2.48 /  Ounce
# B000W7PUMY                     1.14 /  Ounce                    1.27 /  Ounce
# B000WE5DPQ                     0.47 /  Ounce                    0.50 /  Ounce
# B0014CVF98                     0.53 /  Ounce                    0.59 /  Ounce
# ...                                      ...                              ...
# B082VKYZTR                    12.74 /  Ounce                   13.49 /  Ounce
# B082XKWNTM                     1.03 /  Count                    1.09 /  Count
# B08376RLW6                     1.27 /  Count                    1.35 /  Count
# B0848T9CM5                     0.43 /  Count                    0.45 /  Count
# B085ZL9GX6                     2.18 /  Count                    2.30 /  Count
#
#             subscribe_price_15per_USdollars  subscribe_price_5per_USdollars  \
# ASIN
# B000BKGPVM                            25.64                           27.07
# B000ESJR20                            49.86                           52.48
# B000W7PUMY                            27.34                           30.55
# B000WE5DPQ                            22.74                           23.94
# B0014CVF98                             4.20                            4.69
# ...                                     ...                             ...
# B082VKYZTR                            10.19                           10.79
# B082XKWNTM                            24.61                           26.06
# B08376RLW6                            12.71                           13.46
# B0848T9CM5                             8.54                            8.99
# B085ZL9GX6                            43.69                           45.99
#
#             subscribe_5_unitprice subscribe_5_unit subscribe_15_unitprice  \
# ASIN
# B000BKGPVM                   0.48            Ounce                   0.46
# B000ESJR20                   2.48            Ounce                   2.35
# B000W7PUMY                   1.27            Ounce                   1.14
# B000WE5DPQ                   0.50            Ounce                   0.47
# B0014CVF98                   0.59            Ounce                   0.53
# ...                           ...              ...                    ...
# B082VKYZTR                  13.49            Ounce                  12.74
# B082XKWNTM                   1.09            Count                   1.03
# B08376RLW6                   1.35            Count                   1.27
# B0848T9CM5                   0.45            Count                   0.43
# B085ZL9GX6                   2.30            Count                   2.18
#
#            subscribe_15_unit
# ASIN
# B000BKGPVM             Ounce
# B000ESJR20             Ounce
# B000W7PUMY             Ounce
# B000WE5DPQ             Ounce
# B0014CVF98             Ounce
# ...                      ...
# B082VKYZTR             Ounce
# B082XKWNTM             Count
# B08376RLW6             Count
# B0848T9CM5             Count
# B085ZL9GX6             Count
#
# [141 rows x 32 columns]

# %%
coffee.to_csv('coffee2')
